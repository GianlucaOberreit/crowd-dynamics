# %%
import numpy as np
from scipy.integrate import RK45

# %%
# Simulation constants
n_timesteps = 10000
dt = 0.01
n_pedestrians = 1

# %%
# Pedestrian contants
relaxation_times = np.ones(n_pedestrians)[:,None] * 0.5
anisotropic_character = 0.75
sigma = 0
radii = np.ones(n_pedestrians) * 0.3
maximal_speeds = desired_speeds[0] * 1.3
A1, A2, B1, B2 = (0, 2, 0.3, 0.2)
destinations = np.array([[0, 20] for i in range(n_pedestrians)])

# %%
# Simulation state
positions = np.empty((n_timesteps, n_pedestrians, 2,), dtype=float) # [timesteps, pedestrians, (x,y)]
velocities = np.empty((n_timesteps, n_pedestrians, 2,), dtype=float)
desired_speeds = np.empty((n_timesteps, n_pedestrians, 1), dtype=float)

positions[0] = np.array([[i,(-1)**i] for i in range(n_pedestrians)])
desired_speeds[0] = 1 #1.34
velocities[0] = np.array([0,1])

# %%
def driving_force(desired_directions, desired_speeds, velocities):
        return 1/relaxation_times * (desired_speeds * desired_directions - velocities)

# %%
def calc_radii_sum(radii):
    return np.add.outer(radii, radii)

def calc_rel_pos(positions):
    return positions[:, None, :] - positions[None, :, :]

def calc_dists(relative_positions):
    distances = np.linalg.norm(relative_positions, axis=2)
    np.fill_diagonal(distances, np.inf)
    return distances

def calc_norm_vecs(relative_positions, distances):
    return relative_positions /  distances[:, :, None]

def calc_fovs(velocities, norm_vectors):
    velocity_norms = velocities / np.linalg.norm(velocities, axis=1, keepdims=True)
    cos_phi = -np.sum(norm_vectors * velocity_norms[:, None, :], axis=2, keepdims=True)
    return anisotropic_character + (1-anisotropic_character) * (1+cos_phi) / 2

def repulsive_force(positions, radii, velocities):
    radii_sum = calc_radii_sum(radii)
    relative_positions = calc_rel_pos(positions)
    distances = calc_dists(relative_positions)
    norm_vectors = calc_norm_vecs(relative_positions, distances)

    fov = calc_fovs(velocities, norm_vectors)

    repulsive_force_mat = A1 * np.exp( (radii_sum - distances)/B1 )[:,:,None] \
                        * norm_vectors * fov \
                        + A2 * np.exp( (radii_sum - distances)/B2 )[:,:,None] \
                        * norm_vectors
    return np.sum(repulsive_force_mat, axis=1)

# %%
def boundary_force(positions):
    return np.zeros((n_pedestrians,2,))

# %%
def individuality_force(desired_directions):
    e_perp = np.zeros_like(desired_directions)
    e_perp[:,0] = -desired_directions[:,1]
    e_perp[:,1] = desired_directions[:,0]
    return rng.normal(0, sigma, size=n_pedestrians)[:, None]*e_perp

# %%
def total_force(positions, destinations, radii, desired_speeds, velocities):
    desired_directions = destinations - positions
    desired_directions /= np.linalg.norm(desired_directions, axis=1, keepdims=True)
    total_force = driving_force(desired_directions, desired_speeds, velocities) \
                + repulsive_force(positions, radii, velocities) \
                + boundary_force(positions) \
                + individuality_force(desired_directions)
    print("-------------------------------------")
    print(f"driving_force == {driving_force(desired_directions, desired_speeds, velocities)}")
    print(f"repulsive_force == {repulsive_force(positions, radii, velocities)}")
    print(f"boundary_force == {boundary_force(positions)}")
    print(f"individuality_force == {individuality_force(desired_directions)}")
    print("-------------------------------------")

    return total_force

# %%
def calc_desired_speeds(t, positions, desired_speeds, destinations):
    pos0_to_dest = destinations - positions[0]
    pos0_to_dest /= np.linalg.norm(pos0_to_dest, axis=1, keepdims=True)
    pos0_to_pos = positions - positions[0]
    progress_to_dest = np.einsum("nd,nd->n", pos0_to_pos, pos0_to_dest)[:,None]
    average_speeds = progress_to_dest * (0 if t == 0 else 1 / t)
    impatience = 1 - average_speeds / desired_speeds
    return (1-impatience) * desired_speeds[0] + impatience * maximal_speeds

# %%
def test_driving_force():
    desired_directions = np.array([[1,1], [2,1], [1,2]])
    desired_speeds = np.array([[1], [1], [1]])
    velocities = np.array([[1,1], [1,2], [2,1]])
    assert driving_force(desired_directions, desired_speeds, velocities).shape == (3,2)

# %%
rng.normal(0, 0, size=4)[:, None]
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
def test_calc_radii_sum():
    shape = (3,3)
    radii = np.array([.3,.3,.3])
    radii_sum_true = np.ones((3,3)) * 0.6
    radii_sum = calc_radii_sum(radii)
    assert shape == radii_sum.shape
    assert (radii_sum_true == radii_sum).all()

def test_calc_rel_pos():
    shape = (3,3,2)
    positions = np.array([[-1,0], [2,1], [1,3]])
    rel_pos_true = np.array([[[0, 0], [-3, -1], [-2, -3]],
                             [[3, 1], [0, 0], [1, -2]],
                             [[2, 3], [-1, 2], [0, 0]]])
    rel_pos = calc_rel_pos(positions)
    assert shape == rel_pos.shape
    assert (rel_pos_true == rel_pos).all()

def test_calc_dists():
    shape = (3,3)
    positions = np.array([[-1,0], [2,1], [1,3]])
    distances_true = np.array([[np.inf, np.sqrt(10), np.sqrt(13)],
                          [np.sqrt(10), np.inf, np.sqrt(5)],
                          [np.sqrt(13), np.sqrt(5), np.inf]])
    relative_positions = calc_rel_pos(positions)
    distances = calc_dists(relative_positions)
    assert shape == distances.shape
    assert (distances_true == distances).all()

def test_calc_norm_vecs():
    shape = (3,3,2)
    positions = np.array([[-1,0], [2,1], [1,3]])
    norm_vecs_true = np.array([[[0,0], [-3/np.sqrt(10), -1/np.sqrt(10)], [-2/np.sqrt(13), -3/np.sqrt(13)]],
                               [[3/np.sqrt(10), 1/np.sqrt(10)], [0,0], [1/np.sqrt(5), -2/np.sqrt(5)]],
                               [[2/np.sqrt(13), 3/np.sqrt(13)], [-1/np.sqrt(5), 2/np.sqrt(5)], [0,0]]])
    relative_positions = calc_rel_pos(positions)
    norm_vecs = calc_norm_vecs(relative_positions, calc_dists(relative_positions))
    assert shape == norm_vecs.shape
    assert (norm_vecs_true == norm_vecs).all()

def test_calc_fovs():
    shape = (3,3,1)
    positions = np.array([[-1,0], [2,1], [1,3]])
    velocities = np.array([[2,0], [1,-1], [1,1]])
    velocity_norms = np.array([[np.sqrt(2),0], [1,-1], [1,1]]) / np.sqrt(2)
    #cos_phi = np.array([[[0], [-3/np.sqrt(5)], [-2/np.sqrt(13/2)]],
    #                    [[2/np.sqrt(10)], [0], [-3/np.sqrt(5)]],
    #                    [[5/np.sqrt(13)], [1/np.sqrt(5)], [0]]])
    #fov_true = 0.75 + (1-0.75) * (1 + cos_phi) / 2
    relative_positions = calc_rel_pos(positions)
    fov = calc_fovs(velocities, calc_norm_vecs(relative_positions, calc_dists(relative_positions)))
    # Check shape
    assert fov.shape == (3,3,1)
    # Check values in expected range
    assert np.all(fov >= anisotropic_character)
    assert np.all(fov <= 1.0)

# %%
test_calc_radii_sum()
test_calc_rel_pos()
test_calc_dists()
test_calc_norm_vecs()
test_calc_fovs()

# %%
# Other
rng = np.random.default_rng(42)
### temporary
t0 = 0
y0 = np.concatenate((positions[0].flatten(),
                     velocities[0].flatten(),
                     desired_speeds[0].flatten()))
def RK45_step(t, y):
    positions_step = y[:2*n_pedestrians].reshape(positions[0].shape)
    velocities_step = y[2*n_pedestrians:4*n_pedestrians].reshape(velocities[0].shape)
    desired_speeds_step = y[4*n_pedestrians:].reshape(desired_speeds[0].shape)

    new_desired_speeds = calc_desired_speeds(t, positions_step, desired_speeds_step, destinations)
    dpositions = velocities_step
    dvelocities = total_force(positions_step, destinations, radii, desired_speeds_step, velocities_step)
    print("-------------------------------------")
    print(f"positions = {positions_step}")
    print(f"dpositions = {dpositions}")
    print(f"dvelocities = {dvelocities}")
    print("-------------------------------------")
    return np.concatenate((dpositions.flatten(),
                           dvelocities.flatten(),
                           new_desired_speeds.flatten()))
    
### /temporary
class_RK45 = RK45(RK45_step, t0, y0, n_timesteps*dt)
# Out:
# -------------------------------------
# driving_force == [[0. 0.]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0. 1.]]
# dpositions = [[0. 1.]]
# dvelocities = [[0. 0.]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.        0.0274573]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.        1.0105605]]
# dpositions = [[0. 1.]]
# dvelocities = [[0.        0.0274573]]
# -------------------------------------

# %%
for i in range(10):
    class_RK45.step()
# Out:
# -------------------------------------
# driving_force == [[0.         0.05046526]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.01940971]]
# dpositions = [[0. 1.]]
# dvelocities = [[0.         0.05046526]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         0.07349397]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.02911457]]
# dpositions = [[0.         1.00110196]]
# dvelocities = [[0.         0.07349397]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         0.18770974]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.        1.0780191]]
# dpositions = [[0.         1.00707564]]
# dvelocities = [[0.         0.18770974]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         0.20834476]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.        1.0871162]]
# dpositions = [[0.         1.00797264]]
# dvelocities = [[0.         0.20834476]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         0.23156646]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.09798059]]
# dpositions = [[0.         1.01037991]]
# dvelocities = [[0.         0.23156646]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         0.22934871]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.09742615]]
# dpositions = [[0.         1.01148879]]
# dvelocities = [[0.         0.22934871]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         0.47866267]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.21519478]]
# dpositions = [[0.         1.03819208]]
# dvelocities = [[0.         0.47866267]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         0.53800694]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.27757682]]
# dpositions = [[0.         1.08420008]]
# dvelocities = [[0.         0.53800694]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.03253809]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.66096825]]
# dpositions = [[0.         1.21533519]]
# dvelocities = [[0.         1.03253809]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.44528558]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.82186556]]
# dpositions = [[0.         1.07623267]]
# dvelocities = [[0.         1.44528558]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.52476669]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.91876916]]
# dpositions = [[0.         1.12058115]]
# dvelocities = [[0.         1.52476669]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         0.96453125]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.        1.7787103]]
# dpositions = [[0.         1.40069887]]
# dvelocities = [[0.         0.96453125]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.        1.0456756]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         1.94811327]]
# dpositions = [[0.         1.51735097]]
# dvelocities = [[0.        1.0456756]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.06416687]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         2.04868637]]
# dpositions = [[0.         1.58671748]]
# dvelocities = [[0.         1.06416687]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.        1.2270401]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         2.59292487]]
# dpositions = [[0.         1.89834154]]
# dvelocities = [[0.        1.2270401]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.37181183]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.        2.7310744]]
# dpositions = [[0.         1.89583313]]
# dvelocities = [[0.         1.37181183]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.39908404]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         2.87062014]]
# dpositions = [[0.         1.96954385]]
# dvelocities = [[0.         1.39908404]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.19939584]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         2.82069809]]
# dpositions = [[0.         2.06938795]]
# dvelocities = [[0.         1.19939584]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.23253581]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         3.16153617]]
# dpositions = [[0.         2.26693417]]
# dvelocities = [[0.         1.23253581]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.23682459]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         3.36855912]]
# dpositions = [[0.         2.37184789]]
# dvelocities = [[0.         1.23682459]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.31654354]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         4.46232508]]
# dpositions = [[0.         2.86727894]]
# dvelocities = [[0.         1.31654354]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.43017881]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         4.70471338]]
# dpositions = [[0.         2.90562407]]
# dvelocities = [[0.         1.43017881]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.45347762]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         4.98780853]]
# dpositions = [[0.         3.01292812]]
# dvelocities = [[0.         1.45347762]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.27952156]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         4.94431951]]
# dpositions = [[0.         3.09990615]]
# dvelocities = [[0.         1.27952156]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.28859357]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         5.63095355]]
# dpositions = [[0.         3.38332216]]
# dvelocities = [[0.         1.28859357]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.28860828]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         6.04489479]]
# dpositions = [[0.         3.52729082]]
# dvelocities = [[0.         1.28860828]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.31926614]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         8.20197434]]
# dpositions = [[0.         4.23184194]]
# dvelocities = [[0.         1.31926614]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.38074873]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.       8.641197]]
# dpositions = [[0.         4.32907933]]
# dvelocities = [[0.         1.38074873]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.39861111]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.        9.1931948]]
# dpositions = [[0.         4.48012148]]
# dvelocities = [[0.         1.39861111]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.29626518]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[0.         9.16760832]]
# dpositions = [[0.         4.53129444]]
# dvelocities = [[0.         1.29626518]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.29864384]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         10.61057079]]
# dpositions = [[0.         4.94408201]]
# dvelocities = [[0.         1.29864384]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.29812886]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         11.47993286]]
# dpositions = [[0.         5.15132795]]
# dvelocities = [[0.         1.29812886]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.31295722]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         15.99587948]]
# dpositions = [[0.         6.17885602]]
# dvelocities = [[0.         1.31295722]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.35183274]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         16.89403234]]
# dpositions = [[0.         6.34340799]]
# dvelocities = [[0.         1.35183274]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.37038911]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.        18.0458329]]
# dpositions = [[0.         6.56411697]]
# dvelocities = [[0.         1.37038911]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.29702092]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         18.02749085]]
# dpositions = [[0.         6.60080107]]
# dvelocities = [[0.         1.29702092]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.        -30.0817389]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.05401601]]
# dpositions = [[0.         7.19549653]]
# dvelocities = [[  0.        -30.0817389]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.09923628]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.        22.8740358]]
# dpositions = [[ 0.         -8.69302176]]
# dvelocities = [[0.         1.09923628]]
# -------------------------------------
# -------------------------------------
# driving_force == [[   0.         -532.59862221]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[  0.         -99.62033883]]
# dpositions = [[  0.         275.93286822]]
# dvelocities = [[   0.         -532.59862221]]
# -------------------------------------
# -------------------------------------
# driving_force == [[    0.         -2370.00936304]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[   0.         -508.30033293]]
# dpositions = [[   0.         1194.90315481]]
# dvelocities = [[    0.         -2370.00936304]]
# -------------------------------------
# -------------------------------------
# driving_force == [[    0.        -3830.8274531]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[   0.         -867.03960967]]
# dpositions = [[   0.         1925.64334506]]
# dvelocities = [[    0.        -3830.8274531]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         350.35525782]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[  0.         117.29343821]]
# dpositions = [[   0.         -185.40724742]]
# dvelocities = [[  0.         350.35525782]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.29773452]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         18.81806198]]
# dpositions = [[0.         6.75614392]]
# dvelocities = [[0.         1.29773452]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         1.29789902]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.23427846]]
# dpositions = [[0.        6.8339115]]
# dvelocities = [[0.         1.29789902]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -30.18911388]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.33882213]]
# dpositions = [[0.         7.22244678]]
# dvelocities = [[  0.         -30.18911388]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -41.43206727]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.72541375]]
# dpositions = [[ 0.         12.77472363]]
# dvelocities = [[  0.         -41.43206727]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -34.31013328]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.31525641]]
# dpositions = [[0.         9.12725682]]
# dvelocities = [[  0.         -34.31013328]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.        -17.1732854]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.29165025]]
# dpositions = [[0.         0.55883288]]
# dvelocities = [[  0.        -17.1732854]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -13.73120446]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.35224098]]
# dpositions = [[ 0.         -1.30315841]]
# dvelocities = [[  0.         -13.73120446]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -12.84987114]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.15541685]]
# dpositions = [[ 0.         -1.81430048]]
# dvelocities = [[  0.         -12.84987114]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -6.13908669]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.72822263]]
# dpositions = [[ 0.         -5.52206976]]
# dvelocities = [[ 0.         -6.13908669]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -1.16597862]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.58729732]]
# dpositions = [[ 0.        -8.0712686]]
# dvelocities = [[ 0.         -1.16597862]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -0.14853481]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.35716025]]
# dpositions = [[ 0.         -8.65829652]]
# dvelocities = [[ 0.         -0.14853481]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         28.25051004]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.72435754]]
# dpositions = [[ 0.        -5.3926911]]
# dvelocities = [[ 0.         28.25051004]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -15.67715212]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.31798659]]
# dpositions = [[ 0.         -0.25049938]]
# dvelocities = [[  0.         -15.67715212]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -15.08773043]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.28824532]]
# dpositions = [[ 0.         -0.57584303]]
# dvelocities = [[  0.         -15.08773043]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -12.05106222]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.15831981]]
# dpositions = [[ 0.         -2.24734118]]
# dvelocities = [[  0.         -12.05106222]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -11.30034133]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.18604992]]
# dpositions = [[ 0.         -2.64993079]]
# dvelocities = [[  0.         -11.30034133]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -10.77641083]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.11629288]]
# dpositions = [[ 0.         -2.94593249]]
# dvelocities = [[  0.         -10.77641083]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -11.20827213]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.00832755]]
# dpositions = [[ 0.         -2.73000184]]
# dvelocities = [[  0.         -11.20827213]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -10.27436996]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.87966967]]
# dpositions = [[ 0.         -3.25821854]]
# dvelocities = [[  0.         -10.27436996]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -9.90644673]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.78733556]]
# dpositions = [[ 0.         -3.47281297]]
# dvelocities = [[ 0.         -9.90644673]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -8.01092641]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.33603197]]
# dpositions = [[ 0.         -4.57373717]]
# dvelocities = [[ 0.         -8.01092641]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -7.54231851]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.28681763]]
# dpositions = [[ 0.         -4.83527028]]
# dvelocities = [[ 0.         -7.54231851]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -7.21527557]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.15981845]]
# dpositions = [[ 0.         -5.03282821]]
# dvelocities = [[ 0.         -7.21527557]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -7.48484794]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.09242535]]
# dpositions = [[ 0.         -4.89804202]]
# dvelocities = [[ 0.         -7.48484794]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         28.93877903]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.57340707]]
# dpositions = [[ 0.         -5.69116975]]
# dvelocities = [[ 0.         28.93877903]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         21.18553967]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.21934917]]
# dpositions = [[ 0.         -1.74567318]]
# dvelocities = [[ 0.         21.18553967]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         33.83096635]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.        25.5236323]]
# dpositions = [[  0.         -26.10696426]]
# dvelocities = [[ 0.         33.83096635]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         160.20109478]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         42.33238199]]
# dpositions = [[  0.         -89.35325237]]
# dvelocities = [[  0.         160.20109478]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         180.10277167]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         46.00433715]]
# dpositions = [[  0.        -99.3806207]]
# dvelocities = [[  0.         180.10277167]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         25.48718982]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.       18.801701]]
# dpositions = [[ 0.         -3.41436005]]
# dvelocities = [[ 0.         25.48718982]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         28.20540105]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.77785661]]
# dpositions = [[ 0.         -5.37874415]]
# dvelocities = [[ 0.         28.20540105]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         23.61226067]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.58584088]]
# dpositions = [[ 0.         -3.04042878]]
# dvelocities = [[ 0.         23.61226067]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.        10.2562003]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.53136105]]
# dpositions = [[  0.         -14.10252765]]
# dvelocities = [[ 0.        10.2562003]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         68.97312796]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         27.20329868]]
# dpositions = [[  0.         -43.49809831]]
# dvelocities = [[ 0.         68.97312796]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         75.45050493]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.        28.0604732]]
# dpositions = [[  0.         -46.78317034]]
# dvelocities = [[ 0.         75.45050493]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         25.18395817]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.09784399]]
# dpositions = [[ 0.         -3.53406121]]
# dvelocities = [[ 0.         25.18395817]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         27.63076148]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.93805339]]
# dpositions = [[ 0.         -5.13394255]]
# dvelocities = [[ 0.         27.63076148]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         25.41746613]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.85250315]]
# dpositions = [[ 0.         -4.00680877]]
# dvelocities = [[ 0.         25.41746613]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -1.47764642]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.11308338]]
# dpositions = [[ 0.         -8.06553158]]
# dvelocities = [[ 0.         -1.47764642]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         21.27197503]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.36213223]]
# dpositions = [[  0.         -19.45855217]]
# dvelocities = [[ 0.         21.27197503]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.        23.1167182]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         21.45999439]]
# dpositions = [[  0.         -20.40368609]]
# dvelocities = [[ 0.        23.1167182]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         25.61341416]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.47841364]]
# dpositions = [[ 0.         -3.96138009]]
# dvelocities = [[ 0.         25.61341416]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         -7.27578699]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[0. 0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         20.00964326]]
# dpositions = [[ 0.         -5.02454387]]
# dvelocities = [[ 0.         -7.27578699]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         27.51448568]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.96584694]]
# dpositions = [[ 0.         -5.08381978]]
# dvelocities = [[ 0.         27.51448568]]
# -------------------------------------
# -------------------------------------
# driving_force == [[0.         7.36468556]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.        19.7453872]]
# dpositions = [[0.         5.04600872]]
# dvelocities = [[0.         7.36468556]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -28.56859394]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.44987892]]
# dpositions = [[ 0.         23.02241352]]
# dvelocities = [[  0.         -28.56859394]]
# -------------------------------------
# -------------------------------------
# driving_force == [[  0.         -25.41536223]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.         19.24226759]]
# dpositions = [[ 0.         21.45800399]]
# dvelocities = [[  0.         -25.41536223]]
# -------------------------------------
# -------------------------------------
# driving_force == [[ 0.         23.51855861]]
# repulsive_force == [[0. 0.]]
# boundary_force == [[0. 0.]]
# individuality_force == [[-0.  0.]]
# -------------------------------------
# -------------------------------------
# positions = [[ 0.        19.7495864]]
# dpositions = [[ 0.         -3.00895643]]
# dvelocities = [[ 0.         23.51855861]]
# -------------------------------------

# %%
class_RK45.y
# Out:
# array([ 0.        , 19.7495864 ,  0.        , -3.00895643,  8.75032287])

# %%
a = 1
b = 1
a == b != None
# Out:
# True
